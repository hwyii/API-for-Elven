# %% [markdown]
# ## 查询地址普通交易列表

# %%
import requests
import pandas as pd
import pytz
from datetime import datetime
import time
pd.options.mode.chained_assignment = None
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 100)


def processData(apiKey, chainShortName, address, beginTime=None, endTime=None, timezone=None):
    # Base URL and API endpoint
    base_url = "https://www.oklink.com/api/v5/explorer/address/normal-transaction-list"

    # Initialize a DataFrame to hold all transactions
    all_transactions = pd.DataFrame()

    page = 1
    limit = 100  # limit to 100 transactions at maximum per request
    
    while True:
        # Construct query parameters
        query_params = {
            "chainShortName": chainShortName,
            "address": address,
            "page": page,
            "limit": limit
        }

        # Send the API request
        response = requests.get(base_url, headers={'Ok-Access-Key': apiKey}, params=query_params)

        # Ensure the request was successful
        if response.status_code == 200:
            response_data = response.json()
            # Extract the transactions data
            if "data" in response_data and len(response_data["data"]) > 0:
                transactions = response_data["data"][0].get("transactionList", [])
            else:
                transactions = []
            
            if not transactions:
                break  # Exit the loop if there are no transactions
            
            # Convert the transactions data to a DataFrame
            df = pd.json_normalize(transactions)
            
            # Adding custom columns based on specific data
            if not df.empty:
                df.rename(columns={'txId': 'txHash', 'symbol': 'currency', 'transactionTime': 'datetime'}, inplace=True)
                df['datetime'] = pd.to_datetime(pd.to_numeric(df['datetime'], errors='coerce'), unit='ms').dt.strftime('%Y-%m-%dT%H:%M:%SZ')
                df['contactPlatformSlug'] = ''
                df['direction'] = df['to'].apply(lambda x: 'IN' if x == address else 'OUT')
                df['amount'] = df['amount'].astype(float)
                df['contactIdentity'] = df.apply(lambda row: row['to'] if row['from'] == address else row['from'], axis=1)
                df['type'] = df.apply(lambda row: 'CHAIN_TRANSFER_IN' if row['to'] == address else 'CHAIN_TRANSFER_OUT', axis=1)
                df = df[df['state'] == 'success']
                df = df[['type', 'txHash', 'datetime', 'contactIdentity',
                      'contactPlatformSlug', 'direction', 'currency', 'amount', 'txFee']]
                df['txFee'] = df['txFee'].astype(float)
                all_transactions = pd.concat([all_transactions, df], ignore_index=True)
        else:
            print(f"Error: {response.status_code} - {response.text}")
            return pd.DataFrame()  # return an empty DataFrame in case of an error

        page += 1  # Move to the next page

    # 过滤时间
    if not all_transactions.empty:
        if beginTime and endTime and timezone:
            timezone = pytz.timezone(timezone)
            beginTime_tr = timezone.localize(datetime.strptime(beginTime, '%Y-%m-%d').replace(hour=0, minute=0, second=0)).astimezone(pytz.utc).strftime('%Y-%m-%dT%H:%M:%SZ')
            endTime_tr = timezone.localize(datetime.strptime(endTime, '%Y-%m-%d').replace(hour=23, minute=59, second=59)).astimezone(pytz.utc).strftime('%Y-%m-%dT%H:%M:%SZ')
        
            all_transactions = all_transactions[(all_transactions['datetime'] >= beginTime_tr) & (all_transactions['datetime'] <= endTime_tr)]
        
        # Reset index and drop duplicates just in case
        all_transactions.drop_duplicates(subset=['txHash'], inplace=True)
        all_transactions.reset_index(drop=True, inplace=True)
    
    return all_transactions

# %%
# Example usage
apiKey = "d4a4be25-10a1-486a-ac67-7dcd9fa1d7db"
chainShortName = "base"
address = "0x9b6899d37d3200a9eae9f0e24765e8cc2057856d"

df = processData(apiKey, chainShortName, address, beginTime = '2024-01-01', endTime = '2024-07-09', timezone = 'UTC')
df
# Out:
#                   type                                             txHash  \
# 0   CHAIN_TRANSFER_OUT  0xa92cdbea74a8113c6a095883cf005936d82513e9cae5...
# 1   CHAIN_TRANSFER_OUT  0x072bf1cb0b11d7a8889b14b6a3bb789e81a193627080...
# 2   CHAIN_TRANSFER_OUT  0xff63797c07a814af2af42a05a53983f216a216db5fa3...
# 3   CHAIN_TRANSFER_OUT  0x9013ef489346b03f0f33f7145924b91eb1b58afa1361...
# 4   CHAIN_TRANSFER_OUT  0xb7fe7a3d04c942694c11115ebabd24e2c08189ea9550...
# 5   CHAIN_TRANSFER_OUT  0x3a7b87272aca04e830cf2cdddc4de7959644f747bc2c...
# 6   CHAIN_TRANSFER_OUT  0xeda211d3332af0814c9f335a36b65d266e0fffa3d525...
# 7   CHAIN_TRANSFER_OUT  0xe20ca97d0d2f1e92a56918e82fbf1e7de312593843c4...
# 8   CHAIN_TRANSFER_OUT  0x4363be8655b650114e4e1c5117918ddf041359f11204...
# 9   CHAIN_TRANSFER_OUT  0xb47b806324016e9994c65b2f079319da5e2e939f2254...
# 10  CHAIN_TRANSFER_OUT  0xcc9de3a000cac3da7724138b02f2a0cf0756782581ae...
# 11  CHAIN_TRANSFER_OUT  0xd64cc78731950cd43359549632346f07288c21108298...
# 12  CHAIN_TRANSFER_OUT  0x2b13a6063da14f265dec10a31de16b5558b60bfb0fa4...
# 13  CHAIN_TRANSFER_OUT  0xf16089ccfc16adc1c4025cd3cd63d2c2fb8d3d08c373...
# 14  CHAIN_TRANSFER_OUT  0xd65484a621d19917655c877e394132032a9747b09ee8...
# 15  CHAIN_TRANSFER_OUT  0x0e45c4937d2362acf2f56844e323262782e74db155c1...
# 16  CHAIN_TRANSFER_OUT  0xec8d53cd5efda356ca26875832fdbadb87a104a00aef...
# 17  CHAIN_TRANSFER_OUT  0x23ce380beeefad961f7e749cec12b695287b67196406...
# 18  CHAIN_TRANSFER_OUT  0x228eda1f883555105d064c1d2b5868185131639be1a7...
# 19  CHAIN_TRANSFER_OUT  0x82f983aa2cfa9e0c09b44d7edd7a82b83b356694841f...
# 20  CHAIN_TRANSFER_OUT  0x9721a37681c3c41e38575ddb3bf2d6c33eded06dfb1e...
# 21  CHAIN_TRANSFER_OUT  0xa5637dffe49ebc098fb4d783851b6dba108e2064e3ff...
# 22  CHAIN_TRANSFER_OUT  0x4948539f02374a8df7ff5bae0639a84bae29016346a3...
# 23  CHAIN_TRANSFER_OUT  0xf847e0982a365de9cdd0e0882bcd32d9f4324656a8d7...
# 24  CHAIN_TRANSFER_OUT  0xc236dbc690863315b627b163565b6a5d78b482ac4c6e...
# 25  CHAIN_TRANSFER_OUT  0x32f8ba418ee81503decf2301e6f493d8dda6206ebd1d...
# 26  CHAIN_TRANSFER_OUT  0x286e56d7507b6f86b8d48d1ee305003f03a143e5eda2...
# 27  CHAIN_TRANSFER_OUT  0x569aaaae0935524319df59ea730b299d0ba98879e5f8...
# 28  CHAIN_TRANSFER_OUT  0x27659c730eb47c16964080a6df5ecba3aa18bc420aa0...
# 29  CHAIN_TRANSFER_OUT  0x40307c88298d1b0b7df3bc911b254a08de572d5dde46...
# 30  CHAIN_TRANSFER_OUT  0x335fe42a79da8c97fc0b7d45656bde9cac1b2d4d5867...
# 31  CHAIN_TRANSFER_OUT  0x485fa9f162e7ff3f09cda5b9c4efdad57a9ea55db464...
# 32  CHAIN_TRANSFER_OUT  0x2968ac2e431db7085393c0803287ddf29a298e09dfb2...
# 33  CHAIN_TRANSFER_OUT  0x5b95e0c423b6b25c6bd37374b32bfa48a92425d794b1...
# 34  CHAIN_TRANSFER_OUT  0x6c0c2ec6da86b93128e22f5cf705c7379b4c079e07ef...
# 35  CHAIN_TRANSFER_OUT  0x6ba2734fffc065740aa1c3e4aec3a12129f866991aad...
# 36  CHAIN_TRANSFER_OUT  0x1ee23c023a7bfc60666db26bdb06285fc4d9a372f6cb...
# 37  CHAIN_TRANSFER_OUT  0x16cc559f2eb15685e2f7751d5bbc378e3dadaebb7cd1...
# 38  CHAIN_TRANSFER_OUT  0xc1570c671a8ccb1bfb87b33b390db7e1c87109811123...
# 39  CHAIN_TRANSFER_OUT  0xc6d62cfa4ab233bb369d3a5ed55a45643bb5d0d570ac...
# 40  CHAIN_TRANSFER_OUT  0x601b1466ee0fc113f9253c623aba0cd6e02a5eafdb6b...
# 41  CHAIN_TRANSFER_OUT  0xdd142525136d595312d46f8f0e7b14523714c518a1e3...
# 42  CHAIN_TRANSFER_OUT  0xdbb7645a646790b3f51e3fb93dbb1c0cee3626da1836...
# 43  CHAIN_TRANSFER_OUT  0x18232ffed9654b8c190c431eea4fc0a8197dd221a4b3...
# 44  CHAIN_TRANSFER_OUT  0x3a6cc1891ba08a209d59cc327608f5a032e9dc22d4b7...
# 45   CHAIN_TRANSFER_IN  0x60b1f78de83bfa7a8706fd271fa27dd65c0aaa77cbcd...
# 46  CHAIN_TRANSFER_OUT  0xf27b306c4e0b505385465fdb2b8edd8ae58c4c3e9c97...
# 47  CHAIN_TRANSFER_OUT  0x8dfdc33442de221b8e7c2aa2ed937c8fff7cd250b2fb...
# 48  CHAIN_TRANSFER_OUT  0x0c206c222a8ab645d6d536c08421dfef7d62fffedda1...
# 49  CHAIN_TRANSFER_OUT  0x23a537208e18f96c89d16db9ee84868205621770c80c...
# 50  CHAIN_TRANSFER_OUT  0x792cce9cf6428760c384b05280a366a3fd2a9480bcdb...
# 51  CHAIN_TRANSFER_OUT  0x925f9c154bf09272cbf1169560081b8d4940b1d5295c...
# 52  CHAIN_TRANSFER_OUT  0xb723bcb9e873f16191ca3caaca07500f6f72cc907fcb...
# 53  CHAIN_TRANSFER_OUT  0x2f812f0f09678158a22e94113e909cf923ad1de6c247...
# 54  CHAIN_TRANSFER_OUT  0x9075f073602e6dd88fef032c828787ef26025750afc9...
# 55  CHAIN_TRANSFER_OUT  0x91c5cc0756d04c0e352d658bfa4b6d73340c37adbf06...
# 56  CHAIN_TRANSFER_OUT  0x7492356d36f4c0cecd4b688c88752867a755338ed830...
# 29                           OUT      ETH  0.000200  6.428167e-07
# 30                           OUT      ETH  0.000075  6.920066e-06
# 31                           OUT      ETH  0.000075  5.164231e-06
# 32                           OUT      ETH  0.000075  5.045965e-06
# 33                           OUT      ETH  0.000001  3.952351e-06
# 34                           OUT      ETH  0.001654  1.122118e-05
# 35                           OUT      ETH  0.000075  4.592049e-06
# 36                           OUT      ETH  0.000075  4.149071e-06
# 37                           OUT      ETH  0.000075  4.262259e-06
# 38                           OUT      ETH  0.000777  1.614783e-05
# 39                           OUT      ETH  0.000075  1.356639e-05
# 40                           OUT      ETH  0.000075  1.382079e-05
# 41                           OUT      ETH  0.000075  1.324988e-05
# 42                           OUT      ETH  0.000075  1.328778e-05
# 43                           OUT      ETH  0.000075  1.186439e-05
# 44                           OUT      ETH  0.000075  1.086494e-05
# 45                            IN      ETH  0.001000  1.216461e-06
# 46                           OUT      ETH  0.000075  1.134383e-05
# 47                           OUT      ETH  0.000075  1.057215e-05
# 48                           OUT      ETH  0.000075  8.908302e-06
# 49                           OUT      ETH  0.000075  9.432182e-06
# 50                           OUT      ETH  0.000075  9.239829e-06
# 51                           OUT      ETH  0.000000  3.014132e-06
# 52                           OUT      ETH  0.000000  3.752197e-05
# 53                           OUT      ETH  0.000000  3.013002e-06
# 54                           OUT      ETH  0.000075  1.213314e-05
# 55                           OUT      ETH  0.000777  7.572371e-06
# 56                           OUT      ETH  0.000075  1.277217e-05
# 57                           OUT      ETH  0.000100  8.507911e-06
# 58                           OUT      ETH  0.000075  1.045495e-05
# 59                           OUT      ETH  0.000777  7.567124e-06
# 60                           OUT      ETH  0.000075  1.196883e-05
# 61                           OUT      ETH  0.000777  1.094476e-05
# 62                           OUT      ETH  0.000075  1.257439e-05
# 63                           OUT      ETH  0.000777  9.302739e-06
# 64                           OUT      ETH  0.000075  1.278540e-05
# 65                           OUT      ETH  0.000777  8.210886e-06
# 66                           OUT      ETH  0.000075  1.438638e-05
# 67                           OUT      ETH  0.000700  1.031345e-05
# 68                           OUT      ETH  0.000075  1.671271e-05
# 69                           OUT      ETH  0.000350  1.791204e-05
# 70                           OUT      ETH  0.000075  1.593372e-05
# 71                           OUT      ETH  0.000075  1.215269e-05
# 72                           OUT      ETH  0.000075  1.559433e-05
# 73                           OUT      ETH  0.000075  5.226277e-06
# 74                           OUT      ETH  0.000075  5.787201e-06
# 75                           OUT      ETH  0.000075  6.068333e-06
# 76                           OUT      ETH  0.000000  3.047449e-06
# 77                           OUT      ETH  0.000000  1.641208e-06
# 78                           OUT      ETH  0.000000  5.542726e-06
# 79                           OUT      ETH  0.000000  1.502356e-06
# 80                           OUT      ETH  0.000100  4.941966e-06
# 81                           OUT      ETH  0.000075  6.352905e-06

# %%
temp = df
temp.loc[temp['direction'] == 'OUT', 'amount'] *= -1

total_amount = temp['amount'].sum()
# 原始输出有txFee的部分，但是算上了还是对不上
# fee = temp['txFee'].sum()
# total_amount += fee

print("普通交易Total amount:", total_amount)
# Out:
# Total amount: -0.030286700385983915

# %% [markdown]
# ## 查询地址内部交易列表

# %%
import requests
import pandas as pd
import pytz
from datetime import datetime
import time
pd.options.mode.chained_assignment = None
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 100)
def processDataIn(apiKey, chainShortName, address, beginTime=None, endTime=None, timezone=None):
    # Base URL and API endpoint
    base_url = "https://www.oklink.com/api/v5/explorer/address/internal-transaction-list"

    # Initialize a DataFrame to hold all transactions
    all_transactions = pd.DataFrame()

    page = 1
    limit = 100  # limit to 100 transactions at maximum per request
    
    while True:
        # Construct query parameters
        query_params = {
            "chainShortName": chainShortName,
            "address": address,
            "page": page,
            "limit": limit
        }

        # Send the API request
        response = requests.get(base_url, headers={'Ok-Access-Key': apiKey}, params=query_params)

        # Ensure the request was successful
        if response.status_code == 200:
            response_data = response.json()
            # Extract the transactions data
            if "data" in response_data and len(response_data["data"]) > 0:
                transactions = response_data["data"][0].get("transactionList", [])
            else:
                transactions = []
            
            if not transactions:
                break  # Exit the loop if there are no transactions
            
            # Convert the transactions data to a DataFrame
            df = pd.json_normalize(transactions)
            
            # Adding custom columns based on specific data
            if not df.empty:
                df.rename(columns={'txId': 'txHash', 'symbol': 'currency', 'transactionTime': 'datetime'}, inplace=True)
                df['datetime'] = pd.to_datetime(pd.to_numeric(df['datetime'], errors='coerce'), unit='ms').dt.strftime('%Y-%m-%dT%H:%M:%SZ')
                df['contactPlatformSlug'] = ''
                df['direction'] = df['to'].apply(lambda x: 'IN' if x == address else 'OUT')
                df['amount'] = df['amount'].astype(float)
                df['contactIdentity'] = df.apply(lambda row: row['to'] if row['from'] == address else row['from'], axis=1)
                df['type'] = df.apply(lambda row: 'CHAIN_TRANSFER_IN' if row['to'] == address else 'CHAIN_TRANSFER_OUT', axis=1)
                
                df = df[['type', 'txHash', 'datetime', 'contactIdentity',
                      'contactPlatformSlug', 'direction', 'currency', 'amount']]
                
                all_transactions = pd.concat([all_transactions, df], ignore_index=True)
        else:
            print(f"Error: {response.status_code} - {response.text}")
            return pd.DataFrame()  # return an empty DataFrame in case of an error

        page += 1  # Move to the next page

    # 过滤时间
    if not all_transactions.empty:
        if beginTime and endTime and timezone:
            timezone = pytz.timezone(timezone)
            beginTime_tr = timezone.localize(datetime.strptime(beginTime, '%Y-%m-%d').replace(hour=0, minute=0, second=0)).astimezone(pytz.utc).strftime('%Y-%m-%dT%H:%M:%SZ')
            endTime_tr = timezone.localize(datetime.strptime(endTime, '%Y-%m-%d').replace(hour=23, minute=59, second=59)).astimezone(pytz.utc).strftime('%Y-%m-%dT%H:%M:%SZ')
        
            all_transactions = all_transactions[(all_transactions['datetime'] >= beginTime_tr) & (all_transactions['datetime'] <= endTime_tr)]
        
        # Reset index and drop duplicates just in case
        all_transactions.drop_duplicates(subset=['txHash', 'contactIdentity', 'amount'])
        all_transactions.reset_index(drop=True, inplace=True)
    
    return all_transactions

# %%
apiKey = "d4a4be25-10a1-486a-ac67-7dcd9fa1d7db"
chainShortName = "base"
address = "0x9b6899d37d3200a9eae9f0e24765e8cc2057856d"

df_in = processDataIn(apiKey, chainShortName, address, beginTime = '2024-01-01', endTime = '2024-07-10', timezone = 'UTC')
df_in
# Out:
#                  type                                             txHash  \
# 0   CHAIN_TRANSFER_IN  0x7543d3d9b22c852f9983cbcccde3ab7fb5d672553b24...
# 1   CHAIN_TRANSFER_IN  0x498f1c0b8cd9157d97aed4741f05b7ab5ef630e0a78b...
# 2   CHAIN_TRANSFER_IN  0xbb8a2e9c272bf3e00211ad038cc84181f8956a2e338c...
# 3   CHAIN_TRANSFER_IN  0x6c0c2ec6da86b93128e22f5cf705c7379b4c079e07ef...
# 4   CHAIN_TRANSFER_IN  0x49ffc0103d06f2065b6ef2303e57197a84a310ab6fd4...
# 5   CHAIN_TRANSFER_IN  0xb723bcb9e873f16191ca3caaca07500f6f72cc907fcb...
# 6   CHAIN_TRANSFER_IN  0xb723bcb9e873f16191ca3caaca07500f6f72cc907fcb...
# 7   CHAIN_TRANSFER_IN  0xb723bcb9e873f16191ca3caaca07500f6f72cc907fcb...
# 8   CHAIN_TRANSFER_IN  0x0116f2e5eeeafaaf7a1deb75b61e9966aa47f57d7128...
# 9   CHAIN_TRANSFER_IN  0xffec3ecc6ed7448fb2c2fd1cb14abf2531897ecb5efc...
# 10  CHAIN_TRANSFER_IN  0xac9276ad8e3dd7ffaa91de425fb221863f551671d4d0...
#
#                 datetime                             contactIdentity  \
# 0   2024-07-09T03:47:55Z  0x2f59e9086ec8130e21bd052065a9e6b2497bb102
# 1   2024-05-31T02:34:37Z  0x09aea4b2242abc8bb4bb78d537a67a245a7bec64
# 2   2024-04-21T05:15:59Z  0xe8c5b8488feafb5df316be73ede3bdc26571a773
# 3   2024-04-21T02:37:25Z  0x1231deb6f5749ef6ce6943a275a1d3e7486f4eae
# 4   2024-04-19T11:39:49Z  0x09aea4b2242abc8bb4bb78d537a67a245a7bec64
# 5   2024-04-19T10:21:55Z  0x6a1431bb23e08e3209dae3130b441863855fc14b
# 6   2024-04-19T10:21:55Z  0x6a1431bb23e08e3209dae3130b441863855fc14b
# 7   2024-04-19T10:21:55Z  0x6a1431bb23e08e3209dae3130b441863855fc14b
# 8   2024-04-19T08:13:47Z  0x09aea4b2242abc8bb4bb78d537a67a245a7bec64
# 9   2024-04-18T07:39:31Z  0x224d8fd7ab6ad4c6eb4611ce56ef35dec2277f03
# 10  2024-04-18T07:20:59Z  0xe8c5b8488feafb5df316be73ede3bdc26571a773
#
#    contactPlatformSlug direction currency    amount
# 0                             IN      ETH  0.000836
# 1                             IN      ETH  0.019996
# 2                             IN      ETH  0.000998
# 3                             IN      ETH  0.000000
# 4                             IN      ETH  0.000090
# 5                             IN      ETH  0.000218
# 6                             IN      ETH  0.000183
# 7                             IN      ETH  0.000106
# 8                             IN      ETH  0.003715
# 9                             IN      ETH  0.004997
# 10                            IN      ETH  0.000998

# %%
temp = df_in
temp.loc[temp['direction'] == 'OUT', 'amount'] *= -1

total_amount_in = temp['amount'].sum()

# 打印结果
print("内部交易Total amount:", total_amount_in)
# Out:
# 内部交易Total amount: 0.0321367485950947

# %%
amount = total_amount + total_amount_in
print("普通+内部Total amount:", amount)
# Out:
# 普通+内部Total amount: 0.0018500482091107877

# %% [markdown]
# ## 查询地址代币交易列表

# %%
import requests
import pandas as pd
import pytz
from datetime import datetime
import time
pd.options.mode.chained_assignment = None
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 100)
def processDataToken(apiKey, chainShortName, address, protocolType, beginTime=None, endTime=None, timezone=None):
    # Base URL and API endpoint
    base_url = "https://www.oklink.com/api/v5/explorer/address/token-transaction-list"

    # Initialize a DataFrame to hold all transactions
    all_transactions = pd.DataFrame()

    page = 1
    limit = 100  # limit to 100 transactions at maximum per request
    
    while True:
        # Construct query parameters
        query_params = {
            "chainShortName": chainShortName,
            "address": address,
            "protocolType": protocolType,
            "page": page,
            "limit": limit
        }

        # Send the API request
        response = requests.get(base_url, headers={'Ok-Access-Key': apiKey}, params=query_params)

        # Ensure the request was successful
        if response.status_code == 200:
            response_data = response.json()
            # Extract the transactions data
            if "data" in response_data and len(response_data["data"]) > 0:
                transactions = response_data["data"][0].get("transactionList", [])
            else:
                transactions = []
            
            if not transactions:
                break  # Exit the loop if there are no transactions
            
            # Convert the transactions data to a DataFrame
            df = pd.json_normalize(transactions)
            
            # Adding custom columns based on specific data
            if not df.empty:
                df.rename(columns={'txId': 'txHash', 'symbol': 'currency', 'transactionTime': 'datetime'}, inplace=True)
                df['datetime'] = pd.to_datetime(pd.to_numeric(df['datetime'], errors='coerce'), unit='ms').dt.strftime('%Y-%m-%dT%H:%M:%SZ')
                df['contactPlatformSlug'] = ''
                df['direction'] = df['to'].apply(lambda x: 'IN' if x == address else 'OUT')
                df['amount'] = df['amount'].astype(float)
                df['contactIdentity'] = df.apply(lambda row: row['to'] if row['from'] == address else row['from'], axis=1)
                df['type'] = df.apply(lambda row: 'CHAIN_TRANSFER_IN' if row['to'] == address else 'CHAIN_TRANSFER_OUT', axis=1)
                
                df = df[['type', 'txHash', 'datetime', 'contactIdentity',
                      'contactPlatformSlug', 'direction', 'currency', 'amount']]
                
                all_transactions = pd.concat([all_transactions, df], ignore_index=True)
        else:
            print(f"Error: {response.status_code} - {response.text}")
            return pd.DataFrame()  # return an empty DataFrame in case of an error

        page += 1  # Move to the next page

    # 过滤时间
    if not all_transactions.empty:
        if beginTime and endTime and timezone:
            timezone = pytz.timezone(timezone)
            beginTime_tr = timezone.localize(datetime.strptime(beginTime, '%Y-%m-%d').replace(hour=0, minute=0, second=0)).astimezone(pytz.utc).strftime('%Y-%m-%dT%H:%M:%SZ')
            endTime_tr = timezone.localize(datetime.strptime(endTime, '%Y-%m-%d').replace(hour=23, minute=59, second=59)).astimezone(pytz.utc).strftime('%Y-%m-%dT%H:%M:%SZ')
        
            all_transactions = all_transactions[(all_transactions['datetime'] >= beginTime_tr) & (all_transactions['datetime'] <= endTime_tr)]
        
        # Reset index and drop duplicates just in case
        all_transactions.drop_duplicates(subset=['txHash', 'contactIdentity', 'amount'])
        all_transactions.reset_index(drop=True, inplace=True)
    
    return all_transactions

apiKey = "d4a4be25-10a1-486a-ac67-7dcd9fa1d7db"
chainShortName = "base"
address = "0x9b6899d37d3200a9eae9f0e24765e8cc2057856d"
protocolType = "token_20"

df_token = processDataToken(apiKey, chainShortName, address, protocolType, beginTime = '2024-01-01', endTime = '2024-07-10', timezone = 'UTC')
df_token
# Out:
#                   type                                             txHash  \
# 0    CHAIN_TRANSFER_IN  0xea89f975dd20e8460ffde3302358267b0b66e0f4d336...
# 1    CHAIN_TRANSFER_IN  0xff63797c07a814af2af42a05a53983f216a216db5fa3...
# 2   CHAIN_TRANSFER_OUT  0xeda211d3332af0814c9f335a36b65d266e0fffa3d525...
# 3    CHAIN_TRANSFER_IN  0xeda211d3332af0814c9f335a36b65d266e0fffa3d525...
# 4    CHAIN_TRANSFER_IN  0x90b75dff09b1e5ebed40aba4991239f340dfd7c7a27d...
# 5   CHAIN_TRANSFER_OUT  0xe20ca97d0d2f1e92a56918e82fbf1e7de312593843c4...
# 6    CHAIN_TRANSFER_IN  0xe20ca97d0d2f1e92a56918e82fbf1e7de312593843c4...
# 7    CHAIN_TRANSFER_IN  0x787878be5ded8ac1d8e4a27852a58d0bf588bf64b612...
# 8    CHAIN_TRANSFER_IN  0xdd12b832ddc6cbd2ba19dc89600731afee07da16a24d...
# 9    CHAIN_TRANSFER_IN  0xcc9de3a000cac3da7724138b02f2a0cf0756782581ae...
# 10   CHAIN_TRANSFER_IN  0xfd69eb05c74ce7bab4d6de5e0a75b1c96dbf405bfd23...
# 11  CHAIN_TRANSFER_OUT  0xf847e0982a365de9cdd0e0882bcd32d9f4324656a8d7...
# 12   CHAIN_TRANSFER_IN  0xf847e0982a365de9cdd0e0882bcd32d9f4324656a8d7...
# 13   CHAIN_TRANSFER_IN  0x5b95e0c423b6b25c6bd37374b32bfa48a92425d794b1...
# 14   CHAIN_TRANSFER_IN  0xd5b31fb6e1e4e2aebc44ac3662e33a58d58c5f3d2464...
# 15  CHAIN_TRANSFER_OUT  0xb723bcb9e873f16191ca3caaca07500f6f72cc907fcb...
# 16  CHAIN_TRANSFER_OUT  0xb723bcb9e873f16191ca3caaca07500f6f72cc907fcb...
# 17  CHAIN_TRANSFER_OUT  0xb723bcb9e873f16191ca3caaca07500f6f72cc907fcb...
# 18   CHAIN_TRANSFER_IN  0xf5228df1e5d699add3e38c80a579f71cb9dc7093ee2d...
# 19   CHAIN_TRANSFER_IN  0x14d8fe5d89126b07254363259147e5622f857817541b...
# 20  CHAIN_TRANSFER_OUT  0x3676113410b5df1f19e10a7da880f7f11aff6cc20a09...
# 21  CHAIN_TRANSFER_OUT  0x76e2c31c331d72e987721f50f6b4dfc14168a8abfe7e...
# 22   CHAIN_TRANSFER_IN  0x76e2c31c331d72e987721f50f6b4dfc14168a8abfe7e...
# 23   CHAIN_TRANSFER_IN  0x01db56b73463f1ac5f9254fbb0166849930f93db00f9...
#
#                 datetime                             contactIdentity  \
# 0   2024-07-09T03:56:05Z  0x3fc91a3afd70395cd496c647d5a6cc9d4b2b7fad
# 1   2024-07-09T03:54:11Z  0x3fc91a3afd70395cd496c647d5a6cc9d4b2b7fad
# 2   2024-07-09T03:36:13Z  0x39c0926455682a2afb5680045f309848c350de34
# 3   2024-07-09T03:36:13Z  0x0000000000000000000000000000000000000000
# 4   2024-07-02T17:27:45Z  0xd152f549545093347a162dce210e7293f1452150
# 5   2024-06-19T03:59:15Z  0x39c0926455682a2afb5680045f309848c350de34
# 6   2024-06-19T03:59:15Z  0x0000000000000000000000000000000000000000
# 7   2024-06-09T21:52:25Z  0x4ed4e862860bed51a9570b96d89af5e1b0efefed
# 8   2024-06-05T11:03:57Z  0x20fe51a9229eef2cf8ad9e89d91cab9312cf3b7a
# 9   2024-06-03T01:55:49Z  0x9c4de817d24e54a68d5d6253ad2e93d866732376
# 10  2024-05-31T02:36:17Z  0x20fe51a9229eef2cf8ad9e89d91cab9312cf3b7a
# 11  2024-04-21T04:51:01Z  0x4e65fe4dba92790696d040ac24aa414708f5c0ab
# 12  2024-04-21T04:51:01Z  0x0000000000000000000000000000000000000000
# 13  2024-04-21T02:39:49Z  0x3fc91a3afd70395cd496c647d5a6cc9d4b2b7fad
# 14  2024-04-19T11:53:11Z  0x0000000000000000000000000000000000000000
# 15  2024-04-19T10:21:55Z  0x6a1431bb23e08e3209dae3130b441863855fc14b
# 16  2024-04-19T10:21:55Z  0x67b00b46fa4f4f24c03855c5c8013c0b938b3eec
# 17  2024-04-19T10:21:55Z  0x6a1431bb23e08e3209dae3130b441863855fc14b
# 18  2024-04-19T08:03:57Z  0x3fc91a3afd70395cd496c647d5a6cc9d4b2b7fad
# 19  2024-04-19T07:34:07Z  0x1231deb6f5749ef6ce6943a275a1d3e7486f4eae
# 20  2024-04-18T07:32:01Z  0xe45b133ddc64be80252b0e9c75a8e74ef280eed6
# 21  2024-04-18T07:30:41Z  0x56e6983d59bf472ced0e63966a14d94a3a291589
# 22  2024-04-18T07:30:41Z  0x88492051e18a65fe00241a93699a6082ae95c828
# 23  2024-04-18T07:26:03Z  0x3b8000cd10625abdc7370fb47ed4d4a9c6311fd5
#
#    contactPlatformSlug direction                               currency  \
# 0                             IN      UNI visit getunic.pro to swap ETH
# 1                             IN                                   USDC
# 2                            OUT                                  DEGEN
# 3                             IN                                 sDEGEN
# 4                             IN                                 $BEAGL
# 5                            OUT                                  DEGEN
# 6                             IN                                 sDEGEN
# 7                             IN            Claim at: airdrop-degen.com
# 8                             IN  Acces rewards on https://stkether.com
# 9                             IN                                  DEGEN
# 10                            IN  Acces rewards on https://stkether.com
# 11                           OUT                                   USDC
# 12                            IN                               aBasUSDC
# 13                            IN                                   USDC
# 14                            IN                                    MAV
# 15                           OUT                                   USDC
# 16                           OUT                                   USDC
# 17                           OUT                                   USDC
# 18                            IN                                   USDC
# 19                            IN                                   USDC
# 20                           OUT                                   USDC
# 21                           OUT                                  USDbC
# 22                            IN                                   USDC
# 23                            IN                                  USDbC
#
#           amount
# 0   1.200000e+03
# 1   3.062000e-02
# 2   1.000000e-01
# 3   1.000000e-01
# 4   1.000000e+03
# 5   1.000000e-01
# 6   1.000000e-01
# 7   4.500000e+06
# 8   1.000000e+00
# 9   2.000000e+01
# 10  1.000000e+00
# 11  1.000000e-05
# 12  1.000000e-05
# 13  3.164000e-03
# 14  8.100385e-02
# 15  6.751000e-01
# 16  5.652000e-01
# 17  3.297000e-01
# 18  3.074430e-01
# 19  1.066421e+00
# 20  1.000000e-01
# 21  2.985170e-01
# 22  2.984440e-01
# 23  2.985170e-01

# %% [markdown]
# 这个结果比网站上多了一条时间为'2024-06-09T21:52:25Z'的数据

# %%
temp = df_token
temp.loc[temp['direction'] == 'OUT', 'amount'] *= -1

total_amount_token = temp['amount'].sum()

# 打印结果
print("token Total amount:", total_amount_token)
# Out:
# token Total amount: 4502226.454149852
